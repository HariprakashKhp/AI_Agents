# %%
import ollama
from langchain_ollama import OllamaLLM
model_name = "qwen3:latest"

llm = OllamaLLM(
    model=model_name
)

# %%
def generate_story(topic):
    prompt = f"""Write an engaging and educational story about {topic} for beginners. 
            Use simple and clear language to explain basic concepts. 
            Include interesting facts and keep it friendly and encouraging. 
            The story should be around 200-300 words and end with a brief summary of what we learned. 
            Make it perfect for someone just starting to learn about this topic."""
    
    res = llm.invoke(topic)
    return res

topic = "the life cycle of butterflies"
story = generate_story(topic)
print(story)
# Out:
# The life cycle of butterflies is a classic example of **complete metamorphosis**, involving four distinct stages: **egg**, **larva (caterpillar)**, **pupa (chrysalis)**, and **adult**. Here's a detailed breakdown:
#
# ---
#
# ### **1. Egg Stage**
# - **Duration**: A few days to weeks, depending on the species and environmental conditions.
# - **Process**:
#   - Female butterflies lay eggs on specific host plants (e.g., milkweed for monarchs, willow for swallowtails).
#   - Eggs are tiny, often oval or spherical, and may be laid singly or in clusters.
#   - The eggs are usually laid on the underside of leaves to protect them from predators and harsh weather.
# - **Purpose**: The egg provides nutrients for the developing larva.
#
# ---
#
# ### **2. Larva (Caterpillar) Stage**
# - **Duration**: Several weeks to months.
# - **Process**:
#   - The egg hatches into a **caterpillar**, which immediately begins feeding on the host plant.
#   - Caterpillars have strong mandibles for chewing leaves and grow rapidly.
#   - They molt (shed their exoskeleton) multiple times as they grow, with each stage called an **instar**.
#   - Caterpillars are often camouflaged to avoid predators (e.g., green for leaves, bright colors to warn predators of toxicity).
# - **Purpose**: The larva's primary goal is to eat and grow, storing energy for metamorphosis.
#
# ---
#
# ### **3. Pupa (Chrysalis) Stage**
# - **Duration**: A few weeks, depending on temperature and species.
# - **Process**:
#   - The caterpillar finds a safe location (e.g., a branch, leaf, or soil) and forms a **chrysalis** (for butterflies) or **cocoon** (for moths).
#   - Inside the chrysalis, the caterpillar's body undergoes **metamorphosis**—enzymes break down tissues, and new structures (wings, antennae, etc.) form.
#   - The chrysalis is often camouflaged or protected by a thin layer of silk.
# - **Purpose**: This stage is critical for transformation into an adult butterfly.
#
# ---
#
# ### **4. Adult Stage**
# - **Duration**: A few days to several months, depending on the species and environment.
# - **Process**:
#   - The adult butterfly emerges from the chrysalis, expanding and drying its wings.
#   - It feeds on nectar from flowers using a **proboscis** (a coiled feeding tube).
#   - Adults focus on **reproduction**, seeking mates and laying eggs.
#   - Some species (e.g., monarchs) have multiple generations in a single season, while others (e.g., tropical species) may live longer.
# - **Purpose**: The adult's role is to ensure the survival of the next generation by reproducing.
#
# ---
#
# ### **Key Points**
# - **Environmental Factors**: Temperature, humidity, and predation influence each stage.
# - **Host Plants**: Caterpillars rely on specific plants for food, making these plants critical for butterfly survival.
# - **Metamorphosis**: The transformation from caterpillar to butterfly is a remarkable example of biological adaptation.
# - **Ecological Role**: Adult butterflies pollinate flowers, while caterpillars contribute to nutrient cycling in ecosystems.
#
# ---
#
# ### **Example Species**
# - **Monarch Butterfly**: Eggs on milkweed → caterpillars eat milkweed → chrysalis → adult migrates long distances.
# - **Swallowtail Butterfly**: Eggs on willow/lemon trees → caterpillars with bright colors → chrysalis → adult with intricate wing patterns.
#
# This cycle highlights the delicate balance between growth, survival, and reproduction in the natural world! 🦋

# %%
from gtts import gTTS
from IPython.display import Audio
import io

tts = gTTS(story)

audio_bytes = io.BytesIO()
tts.write_to_fp(audio_bytes)
audio_bytes.seek(0)

Audio(audio_bytes.read(), autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
